# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading the csv data into the DataFrame
data = pd.read_csv("/content/Stress1.csv")
data
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 6595             11           17                      0          14         3
# 6596              9           12                      0           8         0
# 6597              4           26                      0           3         1
# 6598             21            0                      1          19         5
# 6599             18            6                      1          15         3
#
# ...

# %%
# printing first 5 rows and last 5 rows of the dataset
data.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
data.tail()
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 6595             11           17                      0          14         3
# 6596              9           12                      0           8         0
# 6597              4           26                      0           3         1
# 6598             21            0                      1          19         5
# 6599             18            6                      1          15         3
#
#       blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 6595               1              3                  2            2
# 6596               3              0                  0            0
# 6597               2              5                  2            2
# 6598               3              1                  4            3
# 6599               3              0                  3            3
#
#       living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
# no.of rows and columns in the dataset
data.shape
# Out:
# (6600, 21)

# %% [markdown]
# this means 303 rows and 14 columns are available in the dataset

# %%
#getting some information of dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6600 entries, 0 to 6599
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 6600 non-null   int64
#  1   self_esteem                   6600 non-null   int64
#  2   mental_health_history         6600 non-null   int64
#  3   depression                    6600 non-null   int64
#  4   headache                      6600 non-null   int64
#  5   blood_pressure                6600 non-null   int64
#  6   sleep_quality                 6600 non-null   int64
#  7   breathing_problem             6600 non-null   int64
#  8   noise_level                   6600 non-null   int64
#  9   living_conditions             6600 non-null   int64
#  10  safety                        6600 non-null   int64
#  11  basic_needs                   6600 non-null   int64
#  12  academic_performance          6600 non-null   int64
# ...

# %%
#checking for missing values
data.isnull().sum()
# Out:
# anxiety_level                   0
# self_esteem                     0
# mental_health_history           0
# depression                      0
# headache                        0
# blood_pressure                  0
# sleep_quality                   0
# breathing_problem               0
# noise_level                     0
# living_conditions               0
# safety                          0
# basic_needs                     0
# academic_performance            0
# study_load                      0
# teacher_student_relationship    0
# future_career_concerns          0
# social_support                  0
# peer_pressure                   0
# extracurricular_activities      0
# bullying                        0
# Target                          0
# dtype: int64

# %%
# statistical measures about the dataset
data.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    6600.000000  6600.000000            6600.000000  6600.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.115240     8.941210               0.499985     7.724080
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  6600.000000     6600.000000    6600.000000        6600.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.408822        0.833259       1.547796           1.400183
# ...

# %%
# checking the distribution of Target variables
data['Target'].value_counts()
# Out:
# 0    2238
# 2    2214
# 1    2148
# Name: Target, dtype: int64

# %% [markdown]
# '1' --> Represents Defective Heart
#
# '0' -->  Represents Healthy Heart

# %%
data.columns
# Out:
# Index(['anxiety_level', 'self_esteem', 'mental_health_history', 'depression',
#        'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem',
#        'noise_level', 'living_conditions', 'safety', 'basic_needs',
#        'academic_performance', 'study_load', 'teacher_student_relationship',
#        'future_career_concerns', 'social_support', 'peer_pressure',
#        'extracurricular_activities', 'bullying', 'Target'],
#       dtype='object')

# %%
x = data[["anxiety_level","self_esteem","mental_health_history","depression","headache","blood_pressure","sleep_quality","breathing_problem","noise_level","living_conditions","safety","basic_needs","academic_performance","study_load","teacher_student_relationship","future_career_concerns","social_support","peer_pressure","extracurricular_activities","bullying"]]

y = data['Target']

# %%
x
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 6595             11           17                      0          14         3
# 6596              9           12                      0           8         0
# 6597              4           26                      0           3         1
# 6598             21            0                      1          19         5
# 6599             18            6                      1          15         3
#
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       1
# 3       2
# 4       1
#        ..
# 6595    1
# 6596    2
# 6597    0
# 6598    2
# 6599    2
# Name: Target, Length: 6600, dtype: int64

# %%
# Splitting the data into training data & testing data


x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20)

# %%
x_train
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 3237              5            9                      1           6         4
# 1735             20            2                      1          22         3
# 2156              2           27                      0           2         1
# 6211             15            1                      1          24         4
# 6251              6            5                      0          19         3
# ...             ...          ...                    ...         ...       ...
# 6330              3           28                      0           6         1
# 2075             20           11                      1          26         4
# 4436             12           21                      0          14         2
# 2356              6           30                      0           1         1
# 395               5           25                      0           6         1
#
# ...

# %%
x_test
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 4179              3           26                      0           4         1
# 3315             11           21                      0          14         3
# 4483              0           26                      0           8         1
# 3748             21           13                      1          16         4
# 5243              1           25                      0           7         1
# ...             ...          ...                    ...         ...       ...
# 3412              5           27                      0           8         1
# 1136             12           21                      0          14         2
# 2653             17            9                      1          27         3
# 3640             21            3                      1          18         4
# 2831             19           13                      1          25         3
#
# ...

# %%
y_train
# Out:
# 3237    1
# 1735    2
# 2156    0
# 6211    2
# 6251    0
#        ..
# 6330    0
# 2075    2
# 4436    1
# 2356    0
# 395     0
# Name: Target, Length: 5280, dtype: int64

# %%
y_test
# Out:
# 4179    0
# 3315    1
# 4483    0
# 3748    2
# 5243    0
#        ..
# 3412    0
# 1136    1
# 2653    2
# 3640    2
# 2831    2
# Name: Target, Length: 1320, dtype: int64

# %%
# Model trainig
# LogisticRegression

model = LogisticRegression()
model.fit(x_train,y_train)  # Here Model undergo training
model.score(x_test,y_test)  # Here Model undergo testing
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8946969696969697

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, ..., 2, 2, 2])

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[399,  14,  25],
#        [ 33, 393,  16],
#        [ 34,  17, 389]])

# %%
# Model evolution

'''
Accuracy on training data

'''

x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction,y_train)

# %%
print("Accuracy on training data: ",training_data_accuracy)
# Out:
# Accuracy on training data:  0.8979166666666667

# %%
'''
Accuracy on testing data

'''

x_test_prediction = model.predict(x_test)
testing_data_accuracy = accuracy_score(x_test_prediction,y_test)

# %%
print("Accuracy on testing data: ",testing_data_accuracy)
# Out:
# Accuracy on testing data:  0.8946969696969697

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(data)
# Out:
# 6600

# %%
len(x_train)
# Out:
# 5280

# %%
len(y_train)
# Out:
# 5280

# %% [markdown]
# LOGISTIC REGRESSION

# %%
classifier=LogisticRegression()

# %%
classifier.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predicted=classifier.predict(x_test)

# %%
predicted
# Out:
# array([0, 0, 0, ..., 1, 2, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,predicted)
# Out:
# 0.8977272727272727

# %% [markdown]
# **RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=40)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=40)

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
y_predicted=model.predict(x_test)

# %%
from sklearn .metrics import pair_confusion_matrix
cm=confusion_matrix(y_test,y_predicted)
cm
# Out:
# array([[456,   0,   0],
#        [  0, 422,   0],
#        [  0,   0, 442]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,5))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
#RESULT OF CORRELATION BETWEEN THE PERCENTAGE OF MENTAL HEALTH AND MENTAL DISORDERS
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **DECISION TREE**

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(random_state=2023)

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(columns=['Target']), data['Target'],
                 test_size=0.2, random_state=1984)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=2023)

# %%
accuracy_decision_tree = tree.score(X_test,y_test)

# %%
print("the accuracy of decision tree is equal to: " + str(accuracy_decision_tree))
# Out:
# the accuracy of decision tree is equal to: 1.0

# %%
tree.score(X_train,y_train)
# Out:
# 1.0

# %% [markdown]
# **KNEIGHBORS CLASSIFIER**

# %%
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier is the KNN machine learning algorithem
KNN = KNeighborsClassifier(n_neighbors=1)

# %%
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
KNN.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# **GRADIENT BOOSTING**

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbtree = GradientBoostingClassifier(learning_rate=0.1,
                                    max_depth=1, random_state=1984)
gbtree.fit(X_train, y_train)
gbtree_score_test=gbtree.score(X_test,y_test)
gbtree_score_train=gbtree.score(X_train,y_train)

print("score of gntree in training data is " + str(gbtree_score_train))
print("score of gbtree in testing data is " + str(gbtree_score_test))
# Out:
# score of gntree in training data is 0.9166666666666666
# score of gbtree in testing data is 0.9015151515151515

# %%
# Predictive system

input_data = (input("enter the feature: "))
print(type(input_data))

# Change the input data as a NumPy array
input_data_as_numpy_array = np.fromstring(input_data, dtype=float, sep=',') # this function converts the input data into numpy
print(input_data_as_numpy_array)

# Reshpe the numpy array because we are predicting
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
print(input_data_reshaped)

prediction = model.predict(input_data_reshaped)
print(prediction)


if(prediction[0] == 0) :
  print('The student mental condition is good')
elif(prediction[0] == 1):
  print('The student mental condition is not good')
  print("The stress level is 1")
elif(prediction[0] == 2):
  print('The student mental condition is not good')
  print("The stress level is 2")

# %%
6
